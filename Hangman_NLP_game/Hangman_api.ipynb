# %% [markdown]
# ### **Approach to the problem**

# %% [markdown]
# I used n-gram interpolation algorithm to enable the game to guess a letter. This method utilizes the statistical properties of language and linguistic patterns to estimate the likelihood of certain letters appearing in specific positions, leading to a more accurate and informed guesses.
#
# Approach:
#
# - The algorithm utilized a cascade of five, four, three, two, and one-gram models with a weighted average approach. The choice of five as the cut-off of the n-gram is based on the observation that as the order of n-grams goes beyond five, the number of unique n-grams encountered in the corpus tends to decrease significantly. Choice of the 5-gram model as the cut-off model was to balance the accuracy of capturing longer-range dependencies and the practical limitations imposed by data sparsity.
#
# - After constructing the n-grams, for each n-gram, the algorithm estimates the probability of the next letter given the context of the partially revealed word.
# The algorithm then assigns weights to each of the n-gram models based on their importance in guessing the letter. This is followed by the multiplication of the probabilities of the n-gram with their respective weights.
#
# - Based on the calculated weighted average probabilities, the algorithm chooses the letter with the highest probability as the next likely occurring letter.
#
# - If no letter is chosen from the above procedure, the algorithm chooses the words from the most common occurring in the corpus with extra weight given to the vowels.

# %%
import json
import requests
import random
import string
import secrets
import time
import re
import collections
from collections import defaultdict

try:
    from urllib.parse import parse_qs, urlencode, urlparse
except ImportError:
    from urlparse import parse_qs, urlparse
    from urllib import urlencode

from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class HangmanAPI(object):
    def __init__(self, access_token=None, session=None, timeout=None):
        self.hangman_url = self.determine_hangman_url()
        self.access_token = access_token
        self.session = session or requests.Session()
        self.timeout = timeout
        #array capturing guessed letters
        self.guessed_letters = []
        #array capturing wrong guesses
        self.wrong_guesses= []

        full_dictionary_location = "/content/drive/MyDrive/DATASET/words_250000_train.txt"
        self.full_dictionary = self.build_dictionary(full_dictionary_location)
        self.unique_alphabets = sorted(set("".join(self.full_dictionary)))
        self.most_freq_alphabets = ['a','e','i','o','u']
        self.prior = [0]*len(self.unique_alphabets)
        self.unigram, self.bigram, self.trigram, self.fourgram, self.fivegram= self.train_ngram()
        self.current_dictionary = []
        #hyperparameters: weights given to ecah of the 5-gram probabilities
        self.weight5 = 0.4
        self.weight4 = 0.25
        self.weight3 = 0.2
        self.weight2 = 0.1
        self.weight1 = 0.05

        #self.weight5 = 0.25
        #self.weight4 = 0.25
        #self.weight3 = 0.42
        #self.weight2 =0.08
        #self.weight1 =1

        #self.weight5 = 0.03864019512995809
        #self.weight4 = 0.15428121558276808
        #self.weight3 = 0.12841833151811646
        #self.weight2 = 0.6786602577691578
        #self.weight1 = 1

    @staticmethod
    def determine_hangman_url():
        links = ['https://trexsim.com', 'https://sg.trexsim.com']

        data = {link: 0 for link in links}

        for link in links:

            requests.get(link)

            for i in range(10):
                s = time.time()
                requests.get(link)
                data[link] = time.time() - s

        link = sorted(data.items(), key=lambda x: x[1])[0][0]
        link += '/trexsim/hangman'
        return link

    def train_ngram(self):
      unigram = defaultdict(lambda : defaultdict(int))
      bigram =  defaultdict(lambda : defaultdict(lambda : defaultdict(int)))
      trigram = defaultdict(lambda : defaultdict(lambda : defaultdict(int)))
      fourgram = defaultdict(lambda : defaultdict (lambda : defaultdict(lambda : defaultdict(int))))
      fivegram = defaultdict(lambda : defaultdict(lambda : defaultdict (lambda : defaultdict(lambda : defaultdict(int)))))

      for word in self.full_dictionary:
          for i in range(len(word)-4):
            bigram[len(word)][word[i]][word[i+1]]+=1
            trigram[word[i]][word[i+1]][word[i+2]]+=1
            fourgram[word[i]][word[i+1]][word[i+2]][word[i+3]]+=1
            fivegram[word[i]][word[i+1]][word[i+2]][word[i+3]][word[i+4]]+=1
          i =  len(word) - 4

          if len(word)==2:
            bigram[len(word)][word[0]][word[1]]+=1
          elif len(word)==3:
            bigram[len(word)][word[0]][word[1]]+=1
            bigram[len(word)][word[1]][word[2]]+=1
            trigram[word[0]][word[1]][word[2]]+=1
          elif len(word)>=4:
            bigram[len(word)][word[i]][word[i+1]]+=1
            trigram[word[i]][word[i+1]][word[i+2]]+=1
            fourgram[word[i]][word[i+1]][word[i+2]][word[i+3]]+=1
          for alphabet in set(word):
            unigram[len(word)][alphabet]+=1
      return unigram, bigram, trigram, fourgram, fivegram

    def fivegram_probs(self,word):
        posterior = [0]*len(self.unique_alphabets)
        total_combinations = 0
        alphabet_count = [0]*len(self.unique_alphabets)

        print(self.fivegram['a']['p']['p']['l']['e'])
        for i in range(len(word)-4):

          #alphabet alphabet alphabet alphabet blank
          if word[i]!='_' and word[i+1]!='_' and word[i+2]!='_' and word[i+3]!='_' and word[i+4]=='_':
            known_alphabet1 = word[i]
            known_alphabet2 = word[i+1]
            known_alphabet3 = word[i+2]
            known_alphabet4 = word[i+3]

            for j, probable_alphabet in enumerate(self.unique_alphabets):
              if self.fivegram[known_alphabet1][known_alphabet2][known_alphabet3][known_alphabet4][probable_alphabet]>0 and probable_alphabet not in self.guessed_letters:
                total_combinations+= self.fivegram[known_alphabet1][known_alphabet2][known_alphabet3][known_alphabet4][probable_alphabet]
                alphabet_count[j]+=  self.fivegram[known_alphabet1][known_alphabet2][known_alphabet3][known_alphabet4][probable_alphabet]

          # alphabet alphabet alphabet blank alphabet
          if word[i]!='_' and word[i+1]!='_' and word[i+2]!='_' and word[i+3]=='_' and word[i+4]!='_':
            known_alphabet1 = word[i]
            known_alphabet2 = word[i+1]
            known_alphabet3 = word[i+2]
            known_alphabet4 = word[i+4]

            for j, probable_alphabet in enumerate(self.unique_alphabets):
              if self.fivegram[known_alphabet1][known_alphabet2][known_alphabet3][probable_alphabet][known_alphabet4]>0 and probable_alphabet not in self.guessed_letters:
                total_combinations+= self.fivegram[known_alphabet1][known_alphabet2][known_alphabet3][probable_alphabet][known_alphabet4]
                alphabet_count[j]+=  self.fivegram[known_alphabet1][known_alphabet2][known_alphabet3][probable_alphabet][known_alphabet4]

          # alphabet alphabet blank alphabet alphabet
          if word[i]!='_' and word[i+1]!='_' and word[i+2]=='_' and word[i+3]!='_' and word[i+4]!='_':
            known_alphabet1 = word[i]
            known_alphabet2 = word[i+1]
            known_alphabet3 = word[i+3]
            known_alphabet4 = word[i+4]

            for j, probable_alphabet in enumerate(self.unique_alphabets):
              if self.fivegram[known_alphabet1][known_alphabet2][probable_alphabet][known_alphabet3][known_alphabet4]>0 and probable_alphabet not in self.guessed_letters:
                total_combinations+= self.fivegram[known_alphabet1][known_alphabet2][probable_alphabet][known_alphabet3][known_alphabet4]
                alphabet_count[j]+=  self.fivegram[known_alphabet1][known_alphabet2][probable_alphabet][known_alphabet3][known_alphabet4]

          # alphabet blank alphabet alphabet alphabet
          if word[i]!='_' and word[i+1]=='_' and word[i+2]!='_' and word[i+3]!='_' and word[i+4]!='_':
            known_alphabet1 = word[i]
            known_alphabet2 = word[i+2]
            known_alphabet3 = word[i+3]
            known_alphabet4 = word[i+4]

            for j, probable_alphabet in enumerate(self.unique_alphabets):
              if self.fivegram[known_alphabet1][probable_alphabet][known_alphabet2][known_alphabet3][known_alphabet4]>0 and probable_alphabet not in self.guessed_letters:
                total_combinations+= self.fivegram[known_alphabet1][probable_alphabet][known_alphabet2][known_alphabet3][known_alphabet4]
                alphabet_count[j]+= self.fivegram[known_alphabet1][probable_alphabet][known_alphabet2][known_alphabet3][known_alphabet4]

          # alphabet blank alphabet alphabet alphabet
          if word[i]=='_' and word[i+1]!='_' and word[i+2]!='_' and word[i+3]!='_' and word[i+4]!='_':
            known_alphabet1 = word[i+1]
            known_alphabet2 = word[i+2]
            known_alphabet3 = word[i+3]
            known_alphabet4 = word[i+4]

            for j, probable_alphabet in enumerate(self.unique_alphabets):
              if self.fivegram[probable_alphabet][known_alphabet1][known_alphabet2][known_alphabet3][known_alphabet4]>0 and probable_alphabet not in self.guessed_letters:
                total_combinations+= self.fivegram[probable_alphabet][known_alphabet1][known_alphabet2][known_alphabet3][known_alphabet4]
                alphabet_count[j]+= self.fivegram[probable_alphabet][known_alphabet1][known_alphabet2][known_alphabet3][known_alphabet4]
        # calculate the probabilities of each letter appearing
        if total_combinations > 0:
                  for i in range(len(self.unique_alphabets)):
                      posterior[i] = alphabet_count[i] / total_combinations

        # interpolate probabilities
        for i, p in enumerate(self.prior):
                  self.prior[i] = p + posterior[i] * self.weight5

        return self.fourgram_probs(word)

    def fourgram_probs(self,word):
        posterior = [0]*len(self.unique_alphabets)
        total_combinations = 0
        alphabet_count = [0]*len(self.unique_alphabets)
        for i in range(len(word)-3):

          #alphabet alphabet alphabet blank
          if word[i]!='_' and word[i+1]!='_' and word[i+2]!='_' and word[i+3]=='_' :
            known_alphabet1 = word[i]
            known_alphabet2 = word[i+1]
            known_alphabet3 = word[i+2]

            for j, probable_alphabet in enumerate(self.unique_alphabets):
              if self.fourgram[known_alphabet1][known_alphabet2][known_alphabet3][probable_alphabet]>0 and probable_alphabet not in self.guessed_letters:
                total_combinations+= self.fourgram[known_alphabet1][known_alphabet2][known_alphabet3][probable_alphabet]
                alphabet_count[j]+=  self.fourgram[known_alphabet1][known_alphabet2][known_alphabet3][probable_alphabet]

          # alphabet alphabet blank alphabet
          if word[i]!='_' and word[i+1]!='_' and word[i+2]=='_' and word[i+3]!='_':
            known_alphabet1 = word[i]
            known_alphabet2 = word[i+1]
            known_alphabet3 = word[i+3]

            for j, probable_alphabet in enumerate(self.unique_alphabets):
              if self.fourgram[known_alphabet1][known_alphabet2][probable_alphabet][known_alphabet3]>0 and probable_alphabet not in self.guessed_letters:
                total_combinations+= self.fourgram[known_alphabet1][known_alphabet2][probable_alphabet][known_alphabet3]
                alphabet_count[j]+=  self.fourgram[known_alphabet1][known_alphabet2][probable_alphabet][known_alphabet3]

          # alphabet blank alphabet alphabet
          if word[i]!='_' and word[i+1]=='_' and word[i+2]!='_' and word[i+3]!='_':
            known_alphabet1 = word[i]
            known_alphabet2 = word[i+2]
            known_alphabet3 = word[i+3]

            for j, probable_alphabet in enumerate(self.unique_alphabets):
              if self.fourgram[known_alphabet1][probable_alphabet][known_alphabet2][known_alphabet3]>0 and probable_alphabet not in self.guessed_letters:
                total_combinations+= self.fourgram[known_alphabet1][probable_alphabet][known_alphabet2][known_alphabet3]
                alphabet_count[j]+=  self.fourgram[known_alphabet1][probable_alphabet][known_alphabet2][known_alphabet3]

          # blank alphabet alphabet alphabet
          if word[i]=='_' and word[i+1]!='_' and word[i+2]!='_' and word[i+3]!='_':
            known_alphabet1 = word[i+1]
            known_alphabet2 = word[i+2]
            known_alphabet3 = word[i+3]

            for j, probable_alphabet in enumerate(self.unique_alphabets):
              if self.fourgram[probable_alphabet][known_alphabet1][known_alphabet2][known_alphabet3]>0 and probable_alphabet not in self.guessed_letters:
                total_combinations+= self.fourgram[probable_alphabet][known_alphabet1][known_alphabet2][known_alphabet3]
                alphabet_count[j]+= self.fourgram[probable_alphabet][known_alphabet1][known_alphabet2][known_alphabet3]

        # calculate the probabilities of each letter appearing
        if total_combinations > 0:
                for i in range(len(self.unique_alphabets)):
                    posterior[i] = alphabet_count[i] / total_combinations

        # interpolate probabilities
        for i, p in enumerate(self.prior):
                self.prior[i] = p + posterior[i] * self.weight4

        return self.trigram_probs(word)


    def trigram_probs(self,word):
        posterior = [0]*len(self.unique_alphabets)
        total_combinations = 0
        alphabet_count = [0]*len(self.unique_alphabets)
        for i in range(len(word)-2):

          #alphabet alphabet blank
          if word[i]!='_' and word[i+1]!='_' and word[i+2]=='_'  :
            known_alphabet1 = word[i]
            known_alphabet2 = word[i+1]

            for j, probable_alphabet in enumerate(self.unique_alphabets):
              if self.trigram[known_alphabet1][known_alphabet2][probable_alphabet]>0 and probable_alphabet not in self.guessed_letters:
                total_combinations+= self.trigram[known_alphabet1][known_alphabet2][probable_alphabet]
                alphabet_count[j]+=  self.trigram[known_alphabet1][known_alphabet2][probable_alphabet]

          # alphabet alphabet alphabet blank alphabet
          if word[i]!='_' and word[i+1]=='_' and word[i+2]!='_' :
            known_alphabet1 = word[i]
            known_alphabet2 = word[i+2]

            for j, probable_alphabet in enumerate(self.unique_alphabets):
              if self.trigram[known_alphabet1][probable_alphabet][known_alphabet2]>0 and probable_alphabet not in self.guessed_letters:
                total_combinations+= self.trigram[known_alphabet1][probable_alphabet][known_alphabet2]
                alphabet_count[j]+=  self.trigram[known_alphabet1][probable_alphabet][known_alphabet2]

          # alphabet alphabet blank alphabet alphabet
          if word[i]=='_' and word[i+1]!='_' and word[i+2]!='_':
            known_alphabet1 = word[i+1]
            known_alphabet2 = word[i+2]

            for j, probable_alphabet in enumerate(self.unique_alphabets):
              if self.trigram[probable_alphabet][known_alphabet1][known_alphabet2]>0 and probable_alphabet not in self.guessed_letters:
                total_combinations+= self.trigram[probable_alphabet][known_alphabet1][known_alphabet2]
                alphabet_count[j]+=  self.trigram[probable_alphabet][known_alphabet1][known_alphabet2]
        # calculate the probabilities of each letter appearing
        if total_combinations > 0:
                  for i in range(len(self.unique_alphabets)):
                      posterior[i] = alphabet_count[i] / total_combinations

        # interpolate probabilities
        for i, p in enumerate(self.prior):
                  self.prior[i] = p + posterior[i] * self.weight3

        return self.bigram_probs(word)

    def bigram_probs(self, word):
        posterior = [0]*len(self.unique_alphabets)
        total_combinations = 0
        alphabet_count = [0]*len(self.unique_alphabets)
        for i in range(len(word)-3):

          #alphabet blank
          if word[i]!='_' and word[i+1]=='_' :
            known_alphabet = word[i]

            for j, probable_alphabet in enumerate(self.unique_alphabets):
              if self.bigram[len(word)][known_alphabet][probable_alphabet]>0 and probable_alphabet not in self.guessed_letters:
                total_combinations+= self.bigram[len(word)][known_alphabet][probable_alphabet]
                alphabet_count[j]+=  self.bigram[len(word)][known_alphabet][probable_alphabet]

          # blank alphabet
          if word[i]=='_' and word[i+1]!='_':
            known_alphabet = word[i+1]

            for j, probable_alphabet in enumerate(self.unique_alphabets):
              if self.bigram[len(word)][probable_alphabet][known_alphabet]>0 and probable_alphabet not in self.guessed_letters:
                total_combinations+= self.bigram[len(word)][probable_alphabet][known_alphabet]
                alphabet_count[j]+=  self.bigram[len(word)][probable_alphabet][known_alphabet]

        # calculate the probabilities of each letter appearing
        if total_combinations > 0:
              for i in range(len(self.unique_alphabets)):
                  posterior[i] = alphabet_count[i] / total_combinations

        # interpolate probabilities
        for i, p in enumerate(self.prior):
              self.prior[i] = p + posterior[i] * self.weight2

        return self.unigram_probs(word)

    def unigram_probs(self, word):

        posterior = [0] * len(self.unique_alphabets)

        total_combinations = 0
        alphabet_count = [0] * len(self.unique_alphabets)

        # traverse the word and find blank spaces
        for i in range(len(word)):
            if word[i] == '_':
                for j, probable_alphabet in enumerate(self.unique_alphabets):
                    if self.unigram[len(word)][probable_alphabet] > 0 and probable_alphabet not in self.guessed_letters:
                        total_combinations += self.unigram[len(word)][probable_alphabet]
                        alphabet_count[j] += self.unigram[len(word)][probable_alphabet]

        if total_combinations > 0:
            for i in range(len(self.unique_alphabets)):
                posterior[i] = alphabet_count[i] / total_combinations

        for i, p in enumerate(self.prior):
            self.prior[i] = p + posterior[i] * self.weight1

        # normalizing the probabilities
        sum_all_probs = sum(self.prior)
        if sum_all_probs > 0:
            for i in range(len(self.prior)):
                self.prior[i] = self.prior[i] / sum_all_probs


        # find letter with largest probability
        max_prob = 0
        guess_char = ''
        for i, char in enumerate(self.unique_alphabets):
            if self.prior[i] > max_prob:
                max_prob = self.prior[i]
                guess_char = char
        if guess_char !='':
          return guess_char
        else:
          letters = self.unique_alphabets.copy()
          random.shuffle(letters)
          shuffled_letters = self.most_freq_alphabets+ letters
          for alphabet in self.most_freq_alphabets:
            if alphabet not in self.guessed_letters:
              return alphabet


    def guess(self, word): # word input example: "_ p p _ e "
        ###############################################
        # Replace with your own "guess" function here #
        ###############################################


        # keep track of incorrect guesses to update the n-grams
        self.incorrect_guesses = list(set(self.guessed_letters) - set(word))
        # clean the word so that we strip away the space characters
        # replace "_" with "." as "." indicates any character in regular expressions
        clean_word = word[::2]

        #getting the probabilities to its initial form before making guesses
        self.prior = [0] * len(self.unique_alphabets)

        guess_letter = self.fivegram_probs(clean_word)



        return guess_letter

    ##########################################################
    # You'll likely not need to modify any of the code below #
    ##########################################################

    def build_dictionary(self, dictionary_file_location):
        text_file = open(dictionary_file_location,"r")
        full_dictionary = text_file.read().splitlines()
        text_file.close()
        return full_dictionary

    def start_game(self, practice=True, verbose=True):
        # reset guessed letters to empty set and current plausible dictionary to the full dictionary
        self.guessed_letters = []
        self.current_dictionary = self.full_dictionary

        response = self.request("/new_game", {"practice":practice})
        if response.get('status')=="approved":
            game_id = response.get('game_id')
            word = response.get('word')
            tries_remains = response.get('tries_remains')
            if verbose:
                print("Successfully start a new game! Game ID: {0}. # of tries remaining: {1}. Word: {2}.".format(game_id, tries_remains, word))
            while tries_remains>0:
                # get guessed letter from user code
                guess_letter = self.guess(word)

                # append guessed letter to guessed letters field in hangman object
                self.guessed_letters.append(guess_letter)
                if verbose:
                    print("Guessing letter: {0}".format(guess_letter))

                try:
                    res = self.request("/guess_letter", {"request":"guess_letter", "game_id":game_id, "letter":guess_letter})
                except HangmanAPIError:
                    print('HangmanAPIError exception caught on request.')
                    continue
                except Exception as e:
                    print('Other exception caught on request.')
                    raise e

                if verbose:
                    print("Sever response: {0}".format(res))
                status = res.get('status')
                tries_remains = res.get('tries_remains')
                if status=="success":
                    if verbose:
                        print("Successfully finished game: {0}".format(game_id))
                    return True
                elif status=="failed":
                    reason = res.get('reason', '# of tries exceeded!')
                    if verbose:
                        print("Failed game: {0}. Because of: {1}".format(game_id, reason))
                    return False
                elif status=="ongoing":
                    word = res.get('word')
        else:
            if verbose:
                print("Failed to start a new game")
        return status=="success"

    def my_status(self):
        return self.request("/my_status", {})

    def request(
            self, path, args=None, post_args=None, method=None):
        if args is None:
            args = dict()
        if post_args is not None:
            method = "POST"

        # Add `access_token` to post_args or args if it has not already been
        # included.
        if self.access_token:
            # If post_args exists, we assume that args either does not exists
            # or it does not need `access_token`.
            if post_args and "access_token" not in post_args:
                post_args["access_token"] = self.access_token
            elif "access_token" not in args:
                args["access_token"] = self.access_token

        time.sleep(0.2)

        num_retry, time_sleep = 50, 2
        for it in range(num_retry):
            try:
                response = self.session.request(
                    method or "GET",
                    self.hangman_url + path,
                    timeout=self.timeout,
                    params=args,
                    data=post_args,
                    verify=False
                )
                break
            except requests.HTTPError as e:
                response = json.loads(e.read())
                raise HangmanAPIError(response)
            except requests.exceptions.SSLError as e:
                if it + 1 == num_retry:
                    raise
                time.sleep(time_sleep)

        headers = response.headers
        if 'json' in headers['content-type']:
            result = response.json()
        elif "access_token" in parse_qs(response.text):
            query_str = parse_qs(response.text)
            if "access_token" in query_str:
                result = {"access_token": query_str["access_token"][0]}
                if "expires" in query_str:
                    result["expires"] = query_str["expires"][0]
            else:
                raise HangmanAPIError(response.json())
        else:
            raise HangmanAPIError('Maintype was not text, or querystring')

        if result and isinstance(result, dict) and result.get("error"):
            raise HangmanAPIError(result)
        return result

class HangmanAPIError(Exception):
    def __init__(self, result):
        self.result = result
        self.code = None
        try:
            self.type = result["error_code"]
        except (KeyError, TypeError):
            self.type = ""

        try:
            self.message = result["error_description"]
        except (KeyError, TypeError):
            try:
                self.message = result["error"]["message"]
                self.code = result["error"].get("code")
                if not self.type:
                    self.type = result["error"].get("type", "")
            except (KeyError, TypeError):
                try:
                    self.message = result["error_msg"]
                except (KeyError, TypeError):
                    self.message = result

        Exception.__init__(self, self.message)

# %%
#making a HnagmanAPI class object
api = HangmanAPI()

# %% [markdown]
# ## Playing practice games:
# You can use the command below to play up to 100,000 practice games.

# %%
for i in range(100):
  api.start_game(practice=1,verbose=True)
  [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
  practice_success_rate = total_practice_successes / total_practice_runs
  print('run %d practice games out of an allotted 100,000. practice success rate so far = %.3f' % (total_practice_runs, practice_success_rate))
# Out:
# Successfully start a new game! Game ID: 1bd39150c449. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# 50
# Guessing letter: i
# Sever response: {'game_id': '1bd39150c449', 'status': 'ongoing', 'tries_remains': 6, 'word': 'i _ _ _ _ _ _ _ _ _ _ _ _ _ i _ _ '}
# 50
# Guessing letter: t
# Sever response: {'game_id': '1bd39150c449', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i _ _ _ _ _ _ _ _ _ _ _ _ _ i _ _ '}
# 50
# Guessing letter: o
# Sever response: {'game_id': '1bd39150c449', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i _ _ _ _ o _ _ _ _ _ _ _ _ i _ _ '}
# 50
# Guessing letter: n
# Sever response: {'game_id': '1bd39150c449', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i _ _ _ n o _ _ _ _ _ _ _ _ i _ _ '}
# 50
# Guessing letter: e
# Sever response: {'game_id': '1bd39150c449', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i _ _ _ n o _ _ _ _ _ e _ _ i _ e '}
# 50
# Guessing letter: s
# Sever response: {'game_id': '1bd39150c449', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i _ _ _ n o s _ _ _ _ e s s i _ e '}
# 50
# Guessing letter: r
# Sever response: {'game_id': '1bd39150c449', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i _ _ _ n o s _ _ _ r e s s i _ e '}
# 50
# Guessing letter: p
# Sever response: {'game_id': '1bd39150c449', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i _ _ _ n o s _ p p r e s s i _ e '}
# 50
# Guessing letter: a
# Sever response: {'game_id': '1bd39150c449', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i _ _ _ n o s _ p p r e s s i _ e '}
# 50
# Guessing letter: v
# Sever response: {'game_id': '1bd39150c449', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i _ _ _ n o s _ p p r e s s i v e '}
# 50
# Guessing letter: u
# Sever response: {'game_id': '1bd39150c449', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i _ _ u n o s u p p r e s s i v e '}
# 50
# Guessing letter: m
# Sever response: {'game_id': '1bd39150c449', 'status': 'success', 'tries_remains': 4, 'word': 'i m m u n o s u p p r e s s i v e '}
# Successfully finished game: 1bd39150c449
# run 2304 practice games out of an allotted 100,000. practice success rate so far = 0.491
# Successfully start a new game! Game ID: ad487b399330. # of tries remaining: 6. Word: _ _ _ .
# 50
# Guessing letter: a
# Sever response: {'game_id': 'ad487b399330', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ '}
# 50
# Guessing letter: s
# Sever response: {'game_id': 'ad487b399330', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ '}
# 50
# Guessing letter: c
# Sever response: {'game_id': 'ad487b399330', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ '}
# 50
# Guessing letter: e
# Sever response: {'game_id': 'ad487b399330', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e _ _ '}
# 50
# Guessing letter: i
# Sever response: {'game_id': 'ad487b399330', 'status': 'ongoing', 'tries_remains': 2, 'word': 'e _ _ '}
# 50
# Guessing letter: o
# Sever response: {'game_id': 'ad487b399330', 'status': 'ongoing', 'tries_remains': 1, 'word': 'e _ _ '}
# 50
# Guessing letter: t
# Sever response: {'game_id': 'ad487b399330', 'status': 'failed', 'tries_remains': 0, 'word': 'e _ _ '}
# Failed game: ad487b399330. Because of: # of tries exceeded!
# run 2305 practice games out of an allotted 100,000. practice success rate so far = 0.491
# Successfully start a new game! Game ID: 100a1728e2be. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# 50
# Guessing letter: e
# Sever response: {'game_id': '100a1728e2be', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ e _ '}
# 50
# Guessing letter: i
# Sever response: {'game_id': '100a1728e2be', 'status': 'ongoing', 'tries_remains': 6, 'word': 'i _ _ _ i _ _ e _ '}
# 50
# Guessing letter: a
# Sever response: {'game_id': '100a1728e2be', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i _ _ _ i _ _ e _ '}
# 50
# Guessing letter: r
# Sever response: {'game_id': '100a1728e2be', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i _ _ r i _ _ e _ '}
# 50
# Guessing letter: t
# Sever response: {'game_id': '100a1728e2be', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i _ _ r i t t e _ '}
# 50
# Guessing letter: n
# Sever response: {'game_id': '100a1728e2be', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n _ r i t t e n '}
# 50
# Guessing letter: o
# Sever response: {'game_id': '100a1728e2be', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i n _ r i t t e n '}
# 50
# Guessing letter: d
# Sever response: {'game_id': '100a1728e2be', 'status': 'ongoing', 'tries_remains': 3, 'word': 'i n _ r i t t e n '}
# 50
# Guessing letter: c
# Sever response: {'game_id': '100a1728e2be', 'status': 'ongoing', 'tries_remains': 2, 'word': 'i n _ r i t t e n '}
# 50
# Guessing letter: g
# Sever response: {'game_id': '100a1728e2be', 'status': 'ongoing', 'tries_remains': 1, 'word': 'i n _ r i t t e n '}
# 50
# Guessing letter: u
# Sever response: {'game_id': '100a1728e2be', 'status': 'failed', 'tries_remains': 0, 'word': 'i n _ r i t t e n '}
# Failed game: 100a1728e2be. Because of: # of tries exceeded!
# run 2306 practice games out of an allotted 100,000. practice success rate so far = 0.490
# Successfully start a new game! Game ID: 2d76047a5ebe. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# 50
# Guessing letter: e
# Sever response: {'game_id': '2d76047a5ebe', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ _ _ '}
# 50
# Guessing letter: r
# Sever response: {'game_id': '2d76047a5ebe', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e _ _ _ _ _ '}
# 50
# Guessing letter: i
# Sever response: {'game_id': '2d76047a5ebe', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ i _ e _ _ _ _ _ '}
# 50
# Guessing letter: n
# Sever response: {'game_id': '2d76047a5ebe', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ i _ e _ _ _ _ _ '}
# 50
# Guessing letter: s
# Sever response: {'game_id': '2d76047a5ebe', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ i _ e _ _ _ _ _ '}
# 50
# Guessing letter: t
# Sever response: {'game_id': '2d76047a5ebe', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ i _ e _ t _ _ _ '}
# 50
# Guessing letter: a
# Sever response: {'game_id': '2d76047a5ebe', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ i _ e _ t _ _ _ '}
# 50
# Guessing letter: c
# Sever response: {'game_id': '2d76047a5ebe', 'status': 'ongoing', 'tries_remains': 2, 'word': 'c i _ e c t _ _ _ '}
# 50
# Guessing letter: d
# Sever response: {'game_id': '2d76047a5ebe', 'status': 'ongoing', 'tries_remains': 1, 'word': 'c i _ e c t _ _ _ '}
# 50
# Guessing letter: l
# Sever response: {'game_id': '2d76047a5ebe', 'status': 'ongoing', 'tries_remains': 1, 'word': 'c i l e c t _ _ _ '}
# 50
# Guessing letter: o
# Sever response: {'game_id': '2d76047a5ebe', 'status': 'ongoing', 'tries_remains': 1, 'word': 'c i l e c t o _ _ '}
# 50
# Guessing letter: m
# Sever response: {'game_id': '2d76047a5ebe', 'status': 'ongoing', 'tries_remains': 1, 'word': 'c i l e c t o m _ '}
# 50
# Guessing letter: y
# Sever response: {'game_id': '2d76047a5ebe', 'status': 'success', 'tries_remains': 1, 'word': 'c i l e c t o m y '}
# Successfully finished game: 2d76047a5ebe
# run 2307 practice games out of an allotted 100,000. practice success rate so far = 0.491
# Successfully start a new game! Game ID: f60d280905c7. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# 50
# Guessing letter: i
# Sever response: {'game_id': 'f60d280905c7', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ _ _ '}
# 50
# Guessing letter: e
# Sever response: {'game_id': 'f60d280905c7', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ e _ '}
# 50
# Guessing letter: n
# Sever response: {'game_id': 'f60d280905c7', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ n _ _ _ _ _ _ _ _ e _ '}
# 50
# Guessing letter: o
# Sever response: {'game_id': 'f60d280905c7', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ n _ _ o _ _ _ _ _ e _ '}
# 50
# Guessing letter: t
# Sever response: {'game_id': 'f60d280905c7', 'status': 'ongoing', 'tries_remains': 5, 'word': 't _ _ n _ _ o _ t _ _ _ e _ '}
# 50
# Guessing letter: s
# Sever response: {'game_id': 'f60d280905c7', 'status': 'ongoing', 'tries_remains': 5, 'word': 't _ _ n s _ o _ t _ _ _ e s '}
# 50
# Guessing letter: r
# Sever response: {'game_id': 'f60d280905c7', 'status': 'ongoing', 'tries_remains': 5, 'word': 't r _ n s _ o r t _ _ _ e s '}
# 50
# Guessing letter: a
# Sever response: {'game_id': 'f60d280905c7', 'status': 'ongoing', 'tries_remains': 5, 'word': 't r a n s _ o r t a _ _ e s '}
# 50
# Guessing letter: p
# Sever response: {'game_id': 'f60d280905c7', 'status': 'ongoing', 'tries_remains': 5, 'word': 't r a n s p o r t a _ _ e s '}
# 50
# Guessing letter: l
# Sever response: {'game_id': 'f60d280905c7', 'status': 'ongoing', 'tries_remains': 5, 'word': 't r a n s p o r t a _ l e s '}
# 50
# Guessing letter: b
# Sever response: {'game_id': 'f60d280905c7', 'status': 'success', 'tries_remains': 5, 'word': 't r a n s p o r t a b l e s '}
# Successfully finished game: f60d280905c7
# run 2308 practice games out of an allotted 100,000. practice success rate so far = 0.491
# Successfully start a new game! Game ID: 946725be8eef. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# 50
# Guessing letter: e
# Sever response: {'game_id': '946725be8eef', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ _ e _ _ '}
# 50
# Guessing letter: r
# Sever response: {'game_id': '946725be8eef', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ e _ _ e _ _ '}
# 50
# Guessing letter: i
# Sever response: {'game_id': '946725be8eef', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ e _ _ e _ _ '}
# 50
# Guessing letter: a
# Sever response: {'game_id': '946725be8eef', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ e _ _ e _ _ '}
# 50
# Guessing letter: n
# Sever response: {'game_id': '946725be8eef', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ e _ _ e _ _ '}
# 50
# Guessing letter: t
# Sever response: {'game_id': '946725be8eef', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ e _ _ e _ t '}
# 50
# Guessing letter: s
# Sever response: {'game_id': '946725be8eef', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ s e _ _ e s t '}
# 50
# Guessing letter: l
# Sever response: {'game_id': '946725be8eef', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ s e _ _ e s t '}
# 50
# Guessing letter: o
# Sever response: {'game_id': '946725be8eef', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ o _ s e _ _ e s t '}
# 50
# Guessing letter: u
# Sever response: {'game_id': '946725be8eef', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ o u s e _ u e s t '}
# 50
# Guessing letter: h
# Sever response: {'game_id': '946725be8eef', 'status': 'ongoing', 'tries_remains': 1, 'word': 'h o u s e _ u e s t '}
# 50
# Guessing letter: q
# Sever response: {'game_id': '946725be8eef', 'status': 'failed', 'tries_remains': 0, 'word': 'h o u s e _ u e s t '}
# Failed game: 946725be8eef. Because of: # of tries exceeded!
# run 2309 practice games out of an allotted 100,000. practice success rate so far = 0.491
# Successfully start a new game! Game ID: 58b313cb85f9. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# 50
# Guessing letter: e
# Sever response: {'game_id': '58b313cb85f9', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ _ _ _ '}
# 50
# Guessing letter: r
# Sever response: {'game_id': '58b313cb85f9', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ _ _ _ _ _ '}
# 50
# Guessing letter: i
# Sever response: {'game_id': '58b313cb85f9', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ _ _ i _ _ '}
# 50
# Guessing letter: n
# Sever response: {'game_id': '58b313cb85f9', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ n _ i _ _ '}
# 50
# Guessing letter: t
# Sever response: {'game_id': '58b313cb85f9', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ n t i _ _ '}
# 50
# Guessing letter: a
# Sever response: {'game_id': '58b313cb85f9', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ a _ _ n t i _ _ '}
# 50
# Guessing letter: o
# Sever response: {'game_id': '58b313cb85f9', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ a _ o n t i _ _ '}
# 50
# Guessing letter: c
# Sever response: {'game_id': '58b313cb85f9', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ a _ o n t i _ _ '}
# 50
# Guessing letter: d
# Sever response: {'game_id': '58b313cb85f9', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ a d o n t i _ _ '}
# 50
# Guessing letter: s
# Sever response: {'game_id': '58b313cb85f9', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ a d o n t i s _ '}
# 50
# Guessing letter: m
# Sever response: {'game_id': '58b313cb85f9', 'status': 'ongoing', 'tries_remains': 4, 'word': 'm e _ a d o n t i s m '}
# 50
# Guessing letter: l
# Sever response: {'game_id': '58b313cb85f9', 'status': 'ongoing', 'tries_remains': 3, 'word': 'm e _ a d o n t i s m '}
# 50
# Guessing letter: g
# Sever response: {'game_id': '58b313cb85f9', 'status': 'success', 'tries_remains': 3, 'word': 'm e g a d o n t i s m '}
# Successfully finished game: 58b313cb85f9
# run 2310 practice games out of an allotted 100,000. practice success rate so far = 0.491
# Successfully start a new game! Game ID: 5ed2633ec7b6. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# 50
# Guessing letter: e
# Sever response: {'game_id': '5ed2633ec7b6', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ e _ '}
# 50
# Guessing letter: a
# Sever response: {'game_id': '5ed2633ec7b6', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ a _ e _ '}
# 50
# Guessing letter: t
# Sever response: {'game_id': '5ed2633ec7b6', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ a _ e _ '}
# 50
# Guessing letter: r
# Sever response: {'game_id': '5ed2633ec7b6', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ a _ e _ '}
# 50
# Guessing letter: l
# Sever response: {'game_id': '5ed2633ec7b6', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ a _ e _ '}
# 50
# Guessing letter: n
# Sever response: {'game_id': '5ed2633ec7b6', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ a _ e _ '}
# 50
# Guessing letter: c
# Sever response: {'game_id': '5ed2633ec7b6', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ _ a _ e _ '}
# 50
# Guessing letter: s
# Sever response: {'game_id': '5ed2633ec7b6', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ _ _ a _ e _ '}
# Failed game: 5ed2633ec7b6. Because of: # of tries exceeded!
# run 2311 practice games out of an allotted 100,000. practice success rate so far = 0.491
# Successfully start a new game! Game ID: 017bfea71f79. # of tries remaining: 6. Word: _ _ _ _ _ .
# 50
# Guessing letter: a
# Sever response: {'game_id': '017bfea71f79', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ '}
# 50
# Guessing letter: e
# Sever response: {'game_id': '017bfea71f79', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ e _ _ '}
# 50
# Guessing letter: s
# Sever response: {'game_id': '017bfea71f79', 'status': 'ongoing', 'tries_remains': 5, 'word': 's _ e _ _ '}
# 50
# Guessing letter: t
# Sever response: {'game_id': '017bfea71f79', 'status': 'ongoing', 'tries_remains': 4, 'word': 's _ e _ _ '}
# 50
# Guessing letter: n
# Sever response: {'game_id': '017bfea71f79', 'status': 'ongoing', 'tries_remains': 4, 'word': 's _ e n _ '}
# 50
# Guessing letter: c
# Sever response: {'game_id': '017bfea71f79', 'status': 'ongoing', 'tries_remains': 3, 'word': 's _ e n _ '}
# 50
# Guessing letter: m
# Sever response: {'game_id': '017bfea71f79', 'status': 'ongoing', 'tries_remains': 2, 'word': 's _ e n _ '}
# 50
# Guessing letter: p
# Sever response: {'game_id': '017bfea71f79', 'status': 'ongoing', 'tries_remains': 1, 'word': 's _ e n _ '}
# 50
# Guessing letter: i
# Sever response: {'game_id': '017bfea71f79', 'status': 'failed', 'tries_remains': 0, 'word': 's _ e n _ '}
# Failed game: 017bfea71f79. Because of: # of tries exceeded!
# run 2312 practice games out of an allotted 100,000. practice success rate so far = 0.490
# Successfully start a new game! Game ID: bff8012737fa. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# 50
# Guessing letter: e
# Sever response: {'game_id': 'bff8012737fa', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ '}
# 50
# Guessing letter: a
# Sever response: {'game_id': 'bff8012737fa', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ a _ _ a '}
# 50
# Guessing letter: r
# Sever response: {'game_id': 'bff8012737fa', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ a _ _ a '}
# 50
# Guessing letter: n
# Sever response: {'game_id': 'bff8012737fa', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ a _ _ a '}
# 50
# Guessing letter: l
# Sever response: {'game_id': 'bff8012737fa', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ a l l a '}
# 50
# Guessing letter: c
# Sever response: {'game_id': 'bff8012737fa', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a _ a l l a '}
# 50
# Guessing letter: t
# Sever response: {'game_id': 'bff8012737fa', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a _ a l l a '}
# 50
# Guessing letter: i
# Sever response: {'game_id': 'bff8012737fa', 'status': 'failed', 'tries_remains': 0, 'word': '_ a _ a l l a '}
# Failed game: bff8012737fa. Because of: # of tries exceeded!
# run 2313 practice games out of an allotted 100,000. practice success rate so far = 0.490
# Successfully start a new game! Game ID: 419c0e0d05a1. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# 50
# Guessing letter: e
# Sever response: {'game_id': '419c0e0d05a1', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ e _ e _ _ _ e _ '}
# 50
# Guessing letter: r
# Sever response: {'game_id': '419c0e0d05a1', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ e _ e _ _ _ e _ '}
# 50
# Guessing letter: n
# Sever response: {'game_id': '419c0e0d05a1', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ n e _ e _ _ _ e _ '}
# 50
# Guessing letter: s
# Sever response: {'game_id': '419c0e0d05a1', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ n e _ e _ _ _ e _ '}
# 50
# Guessing letter: l
# Sever response: {'game_id': '419c0e0d05a1', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ n e _ e _ _ _ e _ '}
# 50
# Guessing letter: i
# Sever response: {'game_id': '419c0e0d05a1', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ n e _ e _ _ _ e _ '}
# 50
# Guessing letter: t
# Sever response: {'game_id': '419c0e0d05a1', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ n e _ e _ _ t e _ '}
# 50
# Guessing letter: a
# Sever response: {'game_id': '419c0e0d05a1', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ n e _ e _ _ t e _ '}
# 50
# Guessing letter: o
# Sever response: {'game_id': '419c0e0d05a1', 'status': 'failed', 'tries_remains': 0, 'word': '_ n e _ e _ _ t e _ '}
# Failed game: 419c0e0d05a1. Because of: # of tries exceeded!
# run 2314 practice games out of an allotted 100,000. practice success rate so far = 0.490
# Successfully start a new game! Game ID: aad293a01d78. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# 50
# Guessing letter: e
# Sever response: {'game_id': 'aad293a01d78', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ '}
# 50
# Guessing letter: a
# Sever response: {'game_id': 'aad293a01d78', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ _ a _ '}
# 50
# Guessing letter: r
# Sever response: {'game_id': 'aad293a01d78', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ _ a _ '}
# 50
# Guessing letter: i
# Sever response: {'game_id': 'aad293a01d78', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ _ _ a _ '}
# 50
# Guessing letter: s
# Sever response: {'game_id': 'aad293a01d78', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a _ _ _ a _ '}
# 50
# Guessing letter: n
# Sever response: {'game_id': 'aad293a01d78', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a _ _ _ a n '}
# 50
# Guessing letter: l
# Sever response: {'game_id': 'aad293a01d78', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a l l _ a n '}
# 50
# Guessing letter: m
# Sever response: {'game_id': 'aad293a01d78', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a l l m a n '}
# 50
# Guessing letter: c
# Sever response: {'game_id': 'aad293a01d78', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ a l l m a n '}
# 50
# Guessing letter: t
# Sever response: {'game_id': 'aad293a01d78', 'status': 'success', 'tries_remains': 1, 'word': 't a l l m a n '}
# Successfully finished game: aad293a01d78
# run 2315 practice games out of an allotted 100,000. practice success rate so far = 0.490
# Successfully start a new game! Game ID: be5c758b7f34. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# 50
# Guessing letter: e
# Sever response: {'game_id': 'be5c758b7f34', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ e _ _ _ '}
# 50
# Guessing letter: r
# Sever response: {'game_id': 'be5c758b7f34', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ r e _ _ _ '}
# 50
# Guessing letter: a
# Sever response: {'game_id': 'be5c758b7f34', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ _ e _ r e _ _ _ '}
# 50
# Guessing letter: p
# Sever response: {'game_id': 'be5c758b7f34', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ e _ r e _ _ _ '}
# 50
# Guessing letter: t
# Sever response: {'game_id': 'be5c758b7f34', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ e _ r e t t _ '}
# 50
# Guessing letter: o
# Sever response: {'game_id': 'be5c758b7f34', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ e _ r e t t o '}
# 50
# Guessing letter: c
# Sever response: {'game_id': 'be5c758b7f34', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a _ _ e _ r e t t o '}
# 50
# Guessing letter: u
# Sever response: {'game_id': 'be5c758b7f34', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ _ e _ r e t t o '}
# 50
# Guessing letter: g
# Sever response: {'game_id': 'be5c758b7f34', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a _ _ e g r e t t o '}
# 50
# Guessing letter: l
# Sever response: {'game_id': 'be5c758b7f34', 'status': 'success', 'tries_remains': 3, 'word': 'a l l e g r e t t o '}
# Successfully finished game: be5c758b7f34
# run 2316 practice games out of an allotted 100,000. practice success rate so far = 0.491
# Successfully start a new game! Game ID: 8c614b821ec0. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# 50
# Guessing letter: e
# Sever response: {'game_id': '8c614b821ec0', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ '}
# 50
# Guessing letter: a
# Sever response: {'game_id': '8c614b821ec0', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ e _ '}
# 50
# Guessing letter: i
# Sever response: {'game_id': '8c614b821ec0', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ i e _ '}
# 50
# Guessing letter: r
# Sever response: {'game_id': '8c614b821ec0', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ i e r '}
# 50
# Guessing letter: t
# Sever response: {'game_id': '8c614b821ec0', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ i e r '}
# 50
# Guessing letter: l
# Sever response: {'game_id': '8c614b821ec0', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ i e r '}
# 50
# Guessing letter: n
# Sever response: {'game_id': '8c614b821ec0', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ i e r '}
# 50
# Guessing letter: s
# Sever response: {'game_id': '8c614b821ec0', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ _ i e r '}
# 50
# Guessing letter: d
# Sever response: {'game_id': '8c614b821ec0', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ _ _ i e r '}
# Failed game: 8c614b821ec0. Because of: # of tries exceeded!
# run 2317 practice games out of an allotted 100,000. practice success rate so far = 0.490
# Successfully start a new game! Game ID: ffa77f06dd6a. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# 50
# Guessing letter: e
# Sever response: {'game_id': 'ffa77f06dd6a', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ e _ _ '}
# 50
# Guessing letter: i
# Sever response: {'game_id': 'ffa77f06dd6a', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ e _ _ '}
# 50
# Guessing letter: r
# Sever response: {'game_id': 'ffa77f06dd6a', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ e r _ '}
# 50
# Guessing letter: t
# Sever response: {'game_id': 'ffa77f06dd6a', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ t e r _ '}
# 50
# Guessing letter: a
# Sever response: {'game_id': 'ffa77f06dd6a', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ a _ t e r _ '}
# 50
# Guessing letter: s
# Sever response: {'game_id': 'ffa77f06dd6a', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ s _ _ a s t e r s '}
# 50
# Guessing letter: l
# Sever response: {'game_id': 'ffa77f06dd6a', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ s _ _ a s t e r s '}
# 50
# Guessing letter: m
# Sever response: {'game_id': 'ffa77f06dd6a', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ s _ m a s t e r s '}
# 50
# Guessing letter: o
# Sever response: {'game_id': 'ffa77f06dd6a', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ s _ m a s t e r s '}
# 50
# Guessing letter: n
# Sever response: {'game_id': 'ffa77f06dd6a', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ s _ m a s t e r s '}
# 50
# Guessing letter: u
# Sever response: {'game_id': 'ffa77f06dd6a', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ u s _ m a s t e r s '}
# 50
# Guessing letter: h
# Sever response: {'game_id': 'ffa77f06dd6a', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ u s h m a s t e r s '}
# 50
# Guessing letter: b
# Sever response: {'game_id': 'ffa77f06dd6a', 'status': 'success', 'tries_remains': 2, 'word': 'b u s h m a s t e r s '}
# Successfully finished game: ffa77f06dd6a
# run 2318 practice games out of an allotted 100,000. practice success rate so far = 0.491
# Successfully start a new game! Game ID: 5dfcd0fd8952. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ .
# 50
# Guessing letter: e
# Sever response: {'game_id': '5dfcd0fd8952', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ _ _ _ _ _ _ '}
# 50
# Guessing letter: i
# Sever response: {'game_id': '5dfcd0fd8952', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ _ _ i _ _ _ '}
# 50
# Guessing letter: n
# Sever response: {'game_id': '5dfcd0fd8952', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ e _ _ _ i _ _ _ '}
# 50
# Guessing letter: r
# Sever response: {'game_id': '5dfcd0fd8952', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ e _ _ r i _ _ _ '}
# 50
# Guessing letter: a
# Sever response: {'game_id': '5dfcd0fd8952', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ a _ e _ _ r i _ a _ '}
# 50
# Guessing letter: c
# Sever response: {'game_id': '5dfcd0fd8952', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a c a _ e _ _ r i c a _ '}
# 50
# Guessing letter: t
# Sever response: {'game_id': '5dfcd0fd8952', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a c a t e _ _ r i c a _ '}
# 50
# Guessing letter: l
# Sever response: {'game_id': '5dfcd0fd8952', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a c a t e _ _ r i c a l '}
# 50
# Guessing letter: d
# Sever response: {'game_id': '5dfcd0fd8952', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a c a t e _ _ r i c a l '}
# 50
# Guessing letter: o
# Sever response: {'game_id': '5dfcd0fd8952', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a c a t e _ o r i c a l '}
# 50
# Guessing letter: s
# Sever response: {'game_id': '5dfcd0fd8952', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a c a t e _ o r i c a l '}
# 50
# Guessing letter: m
# Sever response: {'game_id': '5dfcd0fd8952', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a c a t e _ o r i c a l '}
# 50
# Guessing letter: h
# Sever response: {'game_id': '5dfcd0fd8952', 'status': 'ongoing', 'tries_remains': 1, 'word': 'a c a t e _ o r i c a l '}
# 50
# Guessing letter: g
# Sever response: {'game_id': '5dfcd0fd8952', 'status': 'success', 'tries_remains': 1, 'word': 'a c a t e g o r i c a l '}
# Successfully finished game: 5dfcd0fd8952
# run 2319 practice games out of an allotted 100,000. practice success rate so far = 0.491
# Successfully start a new game! Game ID: 5fb112bba91e. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# 50
# Guessing letter: e
# Sever response: {'game_id': '5fb112bba91e', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ '}
# 50
# Guessing letter: a
# Sever response: {'game_id': '5fb112bba91e', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ e _ '}
# 50
# Guessing letter: i
# Sever response: {'game_id': '5fb112bba91e', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i _ _ _ _ e _ '}
# 50
# Guessing letter: r
# Sever response: {'game_id': '5fb112bba91e', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i _ _ _ _ e _ '}
# 50
# Guessing letter: n
# Sever response: {'game_id': '5fb112bba91e', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i n _ _ _ e _ '}
# 50
# Guessing letter: t
# Sever response: {'game_id': '5fb112bba91e', 'status': 'ongoing', 'tries_remains': 3, 'word': 'i n _ _ _ e _ '}
# 50
# Guessing letter: g
# Sever response: {'game_id': '5fb112bba91e', 'status': 'ongoing', 'tries_remains': 2, 'word': 'i n _ _ _ e _ '}
# 50
# Guessing letter: s
# Sever response: {'game_id': '5fb112bba91e', 'status': 'ongoing', 'tries_remains': 2, 'word': 'i n _ _ s e s '}
# 50
# Guessing letter: o
# Sever response: {'game_id': '5fb112bba91e', 'status': 'ongoing', 'tries_remains': 1, 'word': 'i n _ _ s e s '}
# 50
# Guessing letter: u
# Sever response: {'game_id': '5fb112bba91e', 'status': 'ongoing', 'tries_remains': 1, 'word': 'i n _ u s e s '}
# 50
# Guessing letter: d
# Sever response: {'game_id': '5fb112bba91e', 'status': 'failed', 'tries_remains': 0, 'word': 'i n _ u s e s '}
# Failed game: 5fb112bba91e. Because of: # of tries exceeded!
# run 2320 practice games out of an allotted 100,000. practice success rate so far = 0.491
# Successfully start a new game! Game ID: 17e2fc4abf2b. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ .
# 50
# Guessing letter: e
# Sever response: {'game_id': '17e2fc4abf2b', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ e _ _ _ _ _ _ '}
# 50
# Guessing letter: i
# Sever response: {'game_id': '17e2fc4abf2b', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ e _ _ i _ i _ '}
# 50
# Guessing letter: t
# Sever response: {'game_id': '17e2fc4abf2b', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ e _ _ i t i _ '}
# 50
# Guessing letter: n
# Sever response: {'game_id': '17e2fc4abf2b', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ e _ _ i t i _ '}
# 50
# Guessing letter: o
# Sever response: {'game_id': '17e2fc4abf2b', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ o _ e _ _ i t i _ '}
# 50
# Guessing letter: r
# Sever response: {'game_id': '17e2fc4abf2b', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e r o _ e r _ i t i _ '}
# 50
# Guessing letter: s
# Sever response: {'game_id': '17e2fc4abf2b', 'status': 'ongoing', 'tries_remains': 5, 'word': 's e r o _ e r _ i t i s '}
# 50
# Guessing letter: l
# Sever response: {'game_id': '17e2fc4abf2b', 'status': 'ongoing', 'tries_remains': 4, 'word': 's e r o _ e r _ i t i s '}
# 50
# Guessing letter: m
# Sever response: {'game_id': '17e2fc4abf2b', 'status': 'ongoing', 'tries_remains': 4, 'word': 's e r o _ e r m i t i s '}
# 50
# Guessing letter: v
# Sever response: {'game_id': '17e2fc4abf2b', 'status': 'ongoing', 'tries_remains': 3, 'word': 's e r o _ e r m i t i s '}
# 50
# Guessing letter: p
# Sever response: {'game_id': '17e2fc4abf2b', 'status': 'ongoing', 'tries_remains': 2, 'word': 's e r o _ e r m i t i s '}
# 50
# Guessing letter: d
# Sever response: {'game_id': '17e2fc4abf2b', 'status': 'success', 'tries_remains': 2, 'word': 's e r o d e r m i t i s '}
# Successfully finished game: 17e2fc4abf2b
# run 2321 practice games out of an allotted 100,000. practice success rate so far = 0.491
# Successfully start a new game! Game ID: c58fd8100732. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# 50
# Guessing letter: e
# Sever response: {'game_id': 'c58fd8100732', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ _ '}
# 50
# Guessing letter: i
# Sever response: {'game_id': 'c58fd8100732', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i _ _ _ _ _ _ i _ _ _ _ _ '}
# 50
# Guessing letter: n
# Sever response: {'game_id': 'c58fd8100732', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n _ _ _ _ _ i _ _ _ _ _ '}
# 50
# Guessing letter: t
# Sever response: {'game_id': 'c58fd8100732', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n _ _ _ _ t i _ _ _ _ _ '}
# 50
# Guessing letter: a
# Sever response: {'game_id': 'c58fd8100732', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n _ _ a _ t i _ _ _ a _ '}
# 50
# Guessing letter: s
# Sever response: {'game_id': 'c58fd8100732', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n _ _ a s t i _ _ _ a _ '}
# 50
# Guessing letter: c
# Sever response: {'game_id': 'c58fd8100732', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i n _ _ a s t i _ _ _ a _ '}
# 50
# Guessing letter: l
# Sever response: {'game_id': 'c58fd8100732', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i n _ _ a s t i _ _ l a _ '}
# 50
# Guessing letter: o
# Sever response: {'game_id': 'c58fd8100732', 'status': 'ongoing', 'tries_remains': 3, 'word': 'i n _ _ a s t i _ _ l a _ '}
# 50
# Guessing letter: r
# Sever response: {'game_id': 'c58fd8100732', 'status': 'ongoing', 'tries_remains': 3, 'word': 'i n _ r a s t i _ _ l a r '}
# 50
# Guessing letter: g
# Sever response: {'game_id': 'c58fd8100732', 'status': 'ongoing', 'tries_remains': 2, 'word': 'i n _ r a s t i _ _ l a r '}
# 50
# Guessing letter: u
# Sever response: {'game_id': 'c58fd8100732', 'status': 'ongoing', 'tries_remains': 2, 'word': 'i n _ r a s t i _ u l a r '}
# 50
# Guessing letter: d
# Sever response: {'game_id': 'c58fd8100732', 'status': 'ongoing', 'tries_remains': 1, 'word': 'i n _ r a s t i _ u l a r '}
# 50
# Guessing letter: p
# Sever response: {'game_id': 'c58fd8100732', 'status': 'ongoing', 'tries_remains': 1, 'word': 'i n _ r a s t i p u l a r '}
# 50
# Guessing letter: f
# Sever response: {'game_id': 'c58fd8100732', 'status': 'success', 'tries_remains': 1, 'word': 'i n f r a s t i p u l a r '}
# Successfully finished game: c58fd8100732
# run 2322 practice games out of an allotted 100,000. practice success rate so far = 0.491
# Successfully start a new game! Game ID: 42b6faefbd3f. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# 50
# Guessing letter: e
# Sever response: {'game_id': '42b6faefbd3f', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ e _ _ _ e '}
# 50
# Guessing letter: a
# Sever response: {'game_id': '42b6faefbd3f', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ e a _ _ e '}
# 50
# Guessing letter: r
# Sever response: {'game_id': '42b6faefbd3f', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r e a _ _ e '}
# 50
# Guessing letter: t
# Sever response: {'game_id': '42b6faefbd3f', 'status': 'ongoing', 'tries_remains': 6, 'word': 't r e a _ _ e '}
# 50
# Guessing letter: s
# Sever response: {'game_id': '42b6faefbd3f', 'status': 'ongoing', 'tries_remains': 5, 'word': 't r e a _ _ e '}
# 50
# Guessing letter: d
# Sever response: {'game_id': '42b6faefbd3f', 'status': 'ongoing', 'tries_remains': 4, 'word': 't r e a _ _ e '}
# 50
# Guessing letter: m
# Sever response: {'game_id': '42b6faefbd3f', 'status': 'ongoing', 'tries_remains': 3, 'word': 't r e a _ _ e '}
# 50
# Guessing letter: c
# Sever response: {'game_id': '42b6faefbd3f', 'status': 'ongoing', 'tries_remains': 2, 'word': 't r e a _ _ e '}
# 50
# Guessing letter: k
# Sever response: {'game_id': '42b6faefbd3f', 'status': 'ongoing', 'tries_remains': 1, 'word': 't r e a _ _ e '}
# 50
# Guessing letter: n
# Sever response: {'game_id': '42b6faefbd3f', 'status': 'failed', 'tries_remains': 0, 'word': 't r e a _ _ e '}
# Failed game: 42b6faefbd3f. Because of: # of tries exceeded!
# run 2323 practice games out of an allotted 100,000. practice success rate so far = 0.491
# Successfully start a new game! Game ID: 770551be3315. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# 50
# Guessing letter: e
# Sever response: {'game_id': '770551be3315', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ e _ _ _ _ '}
# 50
# Guessing letter: r
# Sever response: {'game_id': '770551be3315', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e r e _ r _ _ '}
# 50
# Guessing letter: b
# Sever response: {'game_id': '770551be3315', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e r e b r _ _ '}
# 50
# Guessing letter: t
# Sever response: {'game_id': '770551be3315', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e r e b r _ _ '}
# 50
# Guessing letter: a
# Sever response: {'game_id': '770551be3315', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e r e b r _ _ '}
# 50
# Guessing letter: c
# Sever response: {'game_id': '770551be3315', 'status': 'ongoing', 'tries_remains': 4, 'word': 'c e r e b r _ _ '}
# 50
# Guessing letter: o
# Sever response: {'game_id': '770551be3315', 'status': 'ongoing', 'tries_remains': 3, 'word': 'c e r e b r _ _ '}
# 50
# Guessing letter: i
# Sever response: {'game_id': '770551be3315', 'status': 'ongoing', 'tries_remains': 3, 'word': 'c e r e b r i _ '}
# 50
# Guessing letter: n
# Sever response: {'game_id': '770551be3315', 'status': 'success', 'tries_remains': 3, 'word': 'c e r e b r i n '}
# Successfully finished game: 770551be3315
# run 2324 practice games out of an allotted 100,000. practice success rate so far = 0.491
# Successfully start a new game! Game ID: f04e79185ecd. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# 50
# Guessing letter: e
# Sever response: {'game_id': 'f04e79185ecd', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ '}
# 50
# Guessing letter: a
# Sever response: {'game_id': 'f04e79185ecd', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ '}
# 50
# Guessing letter: r
# Sever response: {'game_id': 'f04e79185ecd', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ _ _ '}
# 50
# Guessing letter: i
# Sever response: {'game_id': 'f04e79185ecd', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e i _ _ _ '}
# 50
# Guessing letter: n
# Sever response: {'game_id': 'f04e79185ecd', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e i n _ _ '}
# 50
# Guessing letter: t
# Sever response: {'game_id': 'f04e79185ecd', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e i n t _ '}
# 50
# Guessing letter: h
# Sever response: {'game_id': 'f04e79185ecd', 'status': 'ongoing', 'tries_remains': 4, 'word': 'h e i n t _ '}
# 50
# Guessing letter: o
# Sever response: {'game_id': 'f04e79185ecd', 'status': 'ongoing', 'tries_remains': 3, 'word': 'h e i n t _ '}
# 50
# Guessing letter: u
# Sever response: {'game_id': 'f04e79185ecd', 'status': 'ongoing', 'tries_remains': 2, 'word': 'h e i n t _ '}
# 50
# Guessing letter: l
# Sever response: {'game_id': 'f04e79185ecd', 'status': 'ongoing', 'tries_remains': 1, 'word': 'h e i n t _ '}
# 50
# Guessing letter: s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-1460c19ce64b> in <cell line: 1>()
#       1 for i in range(100):
# ----> 2   api.start_game(practice=1,verbose=True)
#       3   [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
#       4   practice_success_rate = total_practice_successes / total_practice_runs
#       5   print('run %d practice games out of an allotted 100,000. practice success rate so far = %.3f' % (total_practice_runs, practice_success_rate))
#
# <ipython-input-45-beea5e2365c3> in start_game(self, practice, verbose)
#     405
#     406                 try:
# --> 407                     res = self.request("/guess_letter", {"request":"guess_letter", "game_id":game_id, "letter":guess_letter})
#     408                 except HangmanAPIError:
#     409                     print('HangmanAPIError exception caught on request.')
#
# <ipython-input-45-beea5e2365c3> in request(self, path, args, post_args, method)
#     453                 args["access_token"] = self.access_token
#     454
# --> 455         time.sleep(0.2)
#     456
#     457         num_retry, time_sleep = 50, 2
#
# KeyboardInterrupt:
